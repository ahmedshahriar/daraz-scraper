# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedshahriar/daraz-scraper/blob/main/daraz_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Daraz Scraper

# %% [markdown]
# # Reviews for a single product

# %%
import requests
import re
import json

 # customize the header dictionary for your need

headers = {
        'authority': 'www.daraz.com.bd',
        'pragma': 'no-cache',
        'cache-control': 'no-cache',
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'none',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-dest': 'document',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

# change the item_id, page_no and page_size as per the product
# this example will parse reviews of this product https://www.daraz.com.bd/products/mens-stylish-slide-slipper-sandal-i141964811-s1103036896.html

item_id = '141964811'
page_no = 1
page_size = 5

review_url = f'https://my.daraz.com.bd/pdp/review/getReviewList?itemId={item_id}&pageSize={page_size}&filter=0&sort=0&pageNo={page_no}'
review_request = requests.get(review_url, headers=headers)


review_dict_list = json.loads(review_request.text)
review_dict_list
# Out:
# {'bizExtMap': None,
#  'headers': {},
#  'httpStatusCode': 200,
#  'mappingCode': None,
#  'model': {'item': {'categoryId': None,
#    'categoryName': None,
#    'configSku': '141964811_BD',
#    'itemId': 141964811,
#    'itemPic': 'https://static-01.daraz.com.bd/p/a30a2d08d57b20caaabb1a0920ea508d.jpg',
#    'itemTitle': "Men's stylish slide slipper sandal",
#    'itemUrl': 'https://www.daraz.com.bd/mens-stylish-slide-slipper-sandal-141964811-s1065736473.html',
#    'rootCategoryId': None,
#    'rootCategoryName': None,
#    'sellerId': None,
#    'skuId': 1065736473,
#    'skuInfo': None,
#    'subSellerId': None,
#    'subSellerName': None,
#    'subShopUrl': None},
#   'items': [{'avatar': 'https://graph.facebook.com/10220024856031487/picture',
#     'boughtDate': '26 Oct 2020',
#     'buyerEmail': None,
#     'buyerId': 1166755,
#     'buyerName': 'Nurul A.',
#     'canDownloadImage': None,
#     'canEdit': True,
#     'clientType': 'androidApp',
#     'configSku': '141964811_BD',
#     'downVotes': 0,
#     'helpful': True,
#     'imageHost': '//sg-live.slatic.net',
#     'imageQCStatus': 'approved',
#     'images': [{'checkedByPeople': False,
#       'height': 750,
#       'legal': True,
#       'size': 488124,
#       'sort': 1,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1604081226219,
#       'url': 'https://sg-test-11.slatic.net/other/roc/4a7a337bc43682b4d6960a0a5a2a8642.jpg',
#       'width': 1000},
#      {'checkedByPeople': False,
#       'height': 750,
#       'legal': True,
#       'size': 486155,
#       'sort': 2,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1604081226219,
#       'url': 'https://sg-test-11.slatic.net/other/roc/0b2de253720b7079fcc27df202aec882.jpg',
#       'width': 1000},
#      {'checkedByPeople': False,
#       'height': 750,
#       'legal': True,
#       'size': 475302,
#       'sort': 3,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1604081226219,
#       'url': 'https://sg-test-11.slatic.net/other/roc/2d3a9129122d41676ac435f2f64848e1.jpg',
#       'width': 1000}],
#     'isAnonymous': False,
#     'isCompleted': 1,
#     'isExternal': 0,
#     'isGuest': False,
#     'isMeLike': None,
#     'isPurchased': True,
#     'isQced': False,
#     'isReportable': 0,
#     'isVideoReady': None,
#     'itemId': 141964811,
#     'itemPic': 'https://static-01.daraz.com.bd/p/a30a2d08d57b20caaabb1a0920ea508d.jpg',
#     'itemTitle': "Men's stylish slide slipper sandal",
#     'itemUrl': 'https://www.daraz.com.bd/mens-stylish-slide-slipper-sandal-i141964811-s1065736473.html',
#     'lastReviewer': 'SAMIHABINTEFAISALSamiha Binte Faisal',
#     'likeCount': 0,
#     'likeText': None,
#     'originPrice': None,
#     'originalRating': None,
#     'promotion': None,
#     'qcDate': None,
#     'qcReasonId': None,
#     'qcScore': None,
#     'qcTag': None,
#     'rating': 5,
#     'realBuyerName': None,
#     'rejected': False,
#     'rejectionReason': None,
#     'relevanceScore': 62.5,
#     'replies': [{'canReply': False,
#       'helpful': None,
#       'isFollowUp': False,
#       'isMeLike': None,
#       'likeCount': 0,
#       'rejected': False,
#       'rejectionReason': None,
#       'resubmissionMessage': None,
#       'resubmissionTooltip': None,
#       'reviewContent': 'Thank you so much sir',
#       'reviewRateId': 15914233764811,
#       'reviewStatus': 'approved',
#       'reviewTime': '5  months ago',
#       'reviewerBadge': None,
#       'reviewerName': 'Nurul A.'}],
#     'reportDate': None,
#     'reportStatus': None,
#     'reportTimes': 0,
#     'resubmissionMessage': None,
#     'resubmissionTooltip': None,
#     'reviewContent': 'Such a good product. I am happy to got this product. Thanks daraz and sailor. If you interested, can buy.',
#     'reviewRateId': 15828252764811,
#     'reviewStatus': 'approved',
#     'reviewTime': '31 Oct 2020',
#     'reviewTitle': None,
#     'reviewType': 'PRODUCT_REVIEW',
#     'salesPrice': None,
#     'sellerId': 1036040,
#     'sellerName': None,
#     'showUploader': True,
#     'showVideoUploader': False,
#     'skuId': '1065736473',
#     'skuInfo': 'Color Family:…Black & Green, Size:EU:41',
#     'source': None,
#     'submitInfo': {'network': 'WIFI',
#      'os': 'ios',
#      'source': 'myreview',
#      'terminal': 'weex'},
#     'tags': None,
#     'targetId': 141964811,
#     'targetType': 'item',
#     'tradeOrderId': None,
#     'upVotes': 0,
#     'videoCoverUrl': None,
#     'videoId': None,
#     'zonedBoughtDate': None,
#     'zonedReviewTime': None},
#    {'avatar': 'https://static-01.daraz.com.bd/p/5d4a41734db9d1488db3f8206516b677.jpg',
#     'boughtDate': '07 Sep 2020',
#     'buyerEmail': None,
#     'buyerId': 700000444192,
#     'buyerName': 'naimur I.',
#     'canDownloadImage': None,
#     'canEdit': True,
#     'clientType': 'androidApp',
#     'configSku': '141964811_BD',
#     'downVotes': 0,
#     'helpful': True,
#     'imageHost': '//sg-live.slatic.net',
#     'imageQCStatus': 'approved',
#     'images': [{'checkedByPeople': False,
#       'height': 768,
#       'legal': True,
#       'size': 511619,
#       'sort': 1,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1599909630236,
#       'url': 'https://sg-test-11.slatic.net/other/roc/1981aefc426c14b17f135bf9b5504546.jpg',
#       'width': 1024},
#      {'checkedByPeople': False,
#       'height': 1024,
#       'legal': True,
#       'size': 493826,
#       'sort': 2,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1599909630236,
#       'url': 'https://sg-test-11.slatic.net/other/roc/cde4b2c02c9f1e96089aca9b45bf1636.jpg',
#       'width': 768},
#      {'checkedByPeople': False,
#       'height': 768,
#       'legal': True,
#       'size': 506900,
#       'sort': 3,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1599909630236,
#       'url': 'https://sg-test-11.slatic.net/other/roc/1e86309f907b35146bd359fe4272e57b.jpg',
#       'width': 1024}],
#     'isAnonymous': False,
#     'isCompleted': 1,
#     'isExternal': 0,
#     'isGuest': False,
#     'isMeLike': None,
#     'isPurchased': True,
#     'isQced': False,
#     'isReportable': 0,
#     'isVideoReady': None,
#     'itemId': 141964811,
#     'itemPic': 'https://static-01.daraz.com.bd/p/a30a2d08d57b20caaabb1a0920ea508d.jpg',
#     'itemTitle': "Men's stylish slide slipper sandal",
#     'itemUrl': 'https://www.daraz.com.bd/mens-stylish-slide-slipper-sandal-i141964811-s1065736473.html',
#     'lastReviewer': 'Alif, SyedAlif, Syed',
#     'likeCount': 0,
#     'likeText': None,
#     'originPrice': None,
#     'originalRating': None,
#     'promotion': None,
#     'qcDate': None,
#     'qcReasonId': None,
#     'qcScore': None,
#     'qcTag': None,
#     'rating': 5,
#     'realBuyerName': None,
#     'rejected': False,
#     'rejectionReason': None,
#     'relevanceScore': 61.75,
#     'replies': [{'canReply': False,
#       'helpful': None,
#       'isFollowUp': False,
#       'isMeLike': None,
#       'likeCount': 0,
#       'rejected': False,
#       'rejectionReason': None,
#       'resubmissionMessage': None,
#       'resubmissionTooltip': None,
#       'reviewContent': 'Thank you so much sir...apnake bhalo product dite pere amader kase khub bhalo lagche..stay with us',
#       'reviewRateId': 15095489964811,
#       'reviewStatus': 'approved',
#       'reviewTime': '6  months ago',
#       'reviewerBadge': None,
#       'reviewerName': 'naimur I.'}],
#     'reportDate': None,
#     'reportStatus': None,
#     'reportTimes': 0,
#     'resubmissionMessage': None,
#     'resubmissionTooltip': None,
#     'reviewContent': 'original product R 😍😍\nTnq so much eto vlo product dewar jnno\napnara  chaile nite paren..',
#     'reviewRateId': 14951690764811,
#     'reviewStatus': 'approved',
#     'reviewTime': '12 Sep 2020',
#     'reviewTitle': None,
#     'reviewType': 'PRODUCT_REVIEW',
#     'salesPrice': None,
#     'sellerId': 1036040,
#     'sellerName': None,
#     'showUploader': True,
#     'showVideoUploader': False,
#     'skuId': '1065736473',
#     'skuInfo': 'Color Family:…Black & Green, Size:EU:41',
#     'source': None,
#     'submitInfo': {'network': '4G',
#      'os': 'ios',
#      'source': 'myreview',
#      'terminal': 'weex'},
#     'tags': None,
#     'targetId': 141964811,
#     'targetType': 'item',
#     'tradeOrderId': None,
#     'upVotes': 0,
#     'videoCoverUrl': None,
#     'videoId': None,
#     'zonedBoughtDate': None,
#     'zonedReviewTime': None},
#    {'avatar': 'https://graph.facebook.com/590724918429893/picture',
#     'boughtDate': '02 Mar 2021',
#     'buyerEmail': None,
#     'buyerId': 700009599678,
#     'buyerName': 'Chonnochara S.',
#     'canDownloadImage': None,
#     'canEdit': True,
#     'clientType': 'androidApp',
#     'configSku': '141964811_BD',
#     'downVotes': 0,
#     'helpful': True,
#     'imageHost': '//sg-live.slatic.net',
#     'imageQCStatus': 'approved',
#     'images': [{'checkedByPeople': False,
#       'height': 567,
#       'legal': True,
#       'size': 354141,
#       'sort': 1,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1615255379435,
#       'url': 'https://sg-test-11.slatic.net/other/roc/bc9adb394bcebc28642668af3e4384a0.jpg',
#       'width': 1008},
#      {'checkedByPeople': False,
#       'height': 567,
#       'legal': True,
#       'size': 369836,
#       'sort': 2,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1615255379435,
#       'url': 'https://sg-test-11.slatic.net/other/roc/5d55ee1bdfc2d43eb4049e6869e93e4f.jpg',
#       'width': 1008},
#      {'checkedByPeople': False,
#       'height': 567,
#       'legal': True,
#       'size': 341026,
#       'sort': 3,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1615255379435,
#       'url': 'https://sg-test-11.slatic.net/other/roc/2f5527b20bfa1a5058dd18332dfabd28.jpg',
#       'width': 1008}],
#     'isAnonymous': False,
#     'isCompleted': 1,
#     'isExternal': 0,
#     'isGuest': False,
#     'isMeLike': None,
#     'isPurchased': True,
#     'isQced': False,
#     'isReportable': 0,
#     'isVideoReady': None,
#     'itemId': 141964811,
#     'itemPic': 'https://static-01.daraz.com.bd/p/1a4d1855f0e8d7034cc0ed74c8324522.jpg',
#     'itemTitle': "Men's stylish slide slipper sandal",
#     'itemUrl': 'https://www.daraz.com.bd/mens-stylish-slide-slipper-sandal-i141964811-s1065736474.html',
#     'lastReviewer': 'Faisal, SamihaFaisal, Samiha',
#     'likeCount': 0,
#     'likeText': None,
#     'originPrice': None,
#     'originalRating': None,
#     'promotion': None,
#     'qcDate': None,
#     'qcReasonId': None,
#     'qcScore': None,
#     'qcTag': None,
#     'rating': 5,
#     'realBuyerName': None,
#     'rejected': False,
#     'rejectionReason': None,
#     'relevanceScore': 61.6,
#     'replies': None,
#     'reportDate': None,
#     'reportStatus': None,
#     'reportTimes': 0,
#     'resubmissionMessage': None,
#     'resubmissionTooltip': None,
#     'reviewContent': 'যেমনটা দেখেছিলাম,যেমন আসা করেছিলাম তেমনটাই পেয়েছি।thank you daraz,thank you daraz mall.',
#     'reviewRateId': 18791448164811,
#     'reviewStatus': 'approved',
#     'reviewTime': '3  days ago',
#     'reviewTitle': None,
#     'reviewType': 'PRODUCT_REVIEW',
#     'salesPrice': None,
#     'sellerId': 1036040,
#     'sellerName': None,
#     'showUploader': True,
#     'showVideoUploader': False,
#     'skuId': '1065736474',
#     'skuInfo': 'Color Family:…Black & Green, Size:EU:42',
#     'source': None,
#     'submitInfo': {'network': 'WIFI',
#      'os': 'ios',
#      'source': 'order_detail',
#      'terminal': 'weex'},
#     'tags': None,
#     'targetId': 141964811,
#     'targetType': 'item',
#     'tradeOrderId': None,
#     'upVotes': 0,
#     'videoCoverUrl': None,
#     'videoId': None,
#     'zonedBoughtDate': None,
#     'zonedReviewTime': None},
#    {'avatar': None,
#     'boughtDate': '16 Sep 2020',
#     'buyerEmail': None,
#     'buyerId': 700010673053,
#     'buyerName': 'Daraz Customer',
#     'canDownloadImage': None,
#     'canEdit': True,
#     'clientType': 'androidApp',
#     'configSku': '141964811_BD',
#     'downVotes': 0,
#     'helpful': True,
#     'imageHost': '//sg-live.slatic.net',
#     'imageQCStatus': 'approved',
#     'images': [{'checkedByPeople': False,
#       'height': 924,
#       'legal': True,
#       'size': 504571,
#       'sort': 1,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1600520437000,
#       'url': 'https://sg-test-11.slatic.net/other/roc/bb976c3058221996fff76d0fbd7df2bc.jpg',
#       'width': 694},
#      {'checkedByPeople': False,
#       'height': 924,
#       'legal': True,
#       'size': 559595,
#       'sort': 2,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1600520437000,
#       'url': 'https://sg-test-11.slatic.net/other/roc/0684adbf3eb7db6072de53cf9c2515fd.jpg',
#       'width': 694},
#      {'checkedByPeople': False,
#       'height': 924,
#       'legal': True,
#       'size': 557959,
#       'sort': 3,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1600520437000,
#       'url': 'https://sg-test-11.slatic.net/other/roc/538ddc2e84561c21b195360d72613d8a.jpg',
#       'width': 694}],
#     'isAnonymous': True,
#     'isCompleted': 1,
#     'isExternal': 0,
#     'isGuest': False,
#     'isMeLike': None,
#     'isPurchased': True,
#     'isQced': False,
#     'isReportable': 0,
#     'isVideoReady': None,
#     'itemId': 141964811,
#     'itemPic': 'https://static-01.daraz.com.bd/p/a30a2d08d57b20caaabb1a0920ea508d.jpg',
#     'itemTitle': "Men's stylish slide slipper sandal",
#     'itemUrl': 'https://www.daraz.com.bd/mens-stylish-slide-slipper-sandal-i141964811-s1065736472.html',
#     'lastReviewer': 'Alif, SyedAlif, Syed',
#     'likeCount': 0,
#     'likeText': None,
#     'originPrice': None,
#     'originalRating': None,
#     'promotion': None,
#     'qcDate': None,
#     'qcReasonId': None,
#     'qcScore': None,
#     'qcTag': None,
#     'rating': 5,
#     'realBuyerName': None,
#     'rejected': False,
#     'rejectionReason': None,
#     'relevanceScore': 61.45,
#     'replies': [{'canReply': False,
#       'helpful': None,
#       'isFollowUp': False,
#       'isMeLike': None,
#       'likeCount': 0,
#       'rejected': False,
#       'rejectionReason': None,
#       'resubmissionMessage': None,
#       'resubmissionTooltip': None,
#       'reviewContent': 'apnakeo dhonnobad sir...amader theke sob somoy bhalo product paben..amader sathe thakun',
#       'reviewRateId': 15176243864811,
#       'reviewStatus': 'approved',
#       'reviewTime': '6  months ago',
#       'reviewerBadge': None,
#       'reviewerName': 'Roman S.'}],
#     'reportDate': None,
#     'reportStatus': None,
#     'reportTimes': 0,
#     'resubmissionMessage': None,
#     'resubmissionTooltip': None,
#     'reviewContent': 'Thik jemon ta chyci omon tai paice.\ntnxxxx a lot.\nproduct ta onk vlo deyar jonne.\n❤❤❤❤',
#     'reviewRateId': 15138200164811,
#     'reviewStatus': 'approved',
#     'reviewTime': '19 Sep 2020',
#     'reviewTitle': None,
#     'reviewType': 'PRODUCT_REVIEW',
#     'salesPrice': None,
#     'sellerId': 1036040,
#     'sellerName': None,
#     'showUploader': True,
#     'showVideoUploader': False,
#     'skuId': '1065736472',
#     'skuInfo': 'Color Family:…Black & Green, Size:EU:40',
#     'source': None,
#     'submitInfo': {'network': '4G',
#      'os': 'ios',
#      'source': 'order_detail',
#      'terminal': 'weex'},
#     'tags': None,
#     'targetId': 141964811,
#     'targetType': 'item',
#     'tradeOrderId': None,
#     'upVotes': 0,
#     'videoCoverUrl': None,
#     'videoId': None,
#     'zonedBoughtDate': None,
#     'zonedReviewTime': None},
#    {'avatar': 'https://lh4.googleusercontent.com/-mC2MD21DXaQ/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuclg3ujyEdtVVG9o5neGOMjN6sByfw/s96-c/photo.jpg',
#     'boughtDate': '26 Feb 2021',
#     'buyerEmail': None,
#     'buyerId': 700024311392,
#     'buyerName': 'Sumaiya A.',
#     'canDownloadImage': None,
#     'canEdit': True,
#     'clientType': 'androidApp',
#     'configSku': '141964811_BD',
#     'downVotes': 0,
#     'helpful': True,
#     'imageHost': '//sg-live.slatic.net',
#     'imageQCStatus': 'approved',
#     'images': [{'checkedByPeople': False,
#       'height': 562,
#       'legal': True,
#       'size': 438819,
#       'sort': 1,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1614678076000,
#       'url': 'https://sg-test-11.slatic.net/other/roc/69b0f17bf03aebb3ed61f5b1889ebfc7.jpg',
#       'width': 1000},
#      {'checkedByPeople': False,
#       'height': 1000,
#       'legal': True,
#       'size': 360635,
#       'sort': 2,
#       'status': 'approved',
#       'title': '',
#       'uploadTime': 1614678076000,
#       'url': 'https://sg-test-11.slatic.net/other/roc/df077c9b9972ea79b79abecc601ce190.jpg',
#       'width': 562}],
#     'isAnonymous': False,
#     'isCompleted': 1,
#     'isExternal': 0,
#     'isGuest': False,
#     'isMeLike': None,
#     'isPurchased': True,
#     'isQced': False,
#     'isReportable': 0,
#     'isVideoReady': None,
#     'itemId': 141964811,
#     'itemPic': 'https://static-01.daraz.com.bd/p/fc113365990b6368954630a02914f647.jpg',
#     'itemTitle': "Men's stylish slide slipper sandal",
#     'itemUrl': 'https://www.daraz.com.bd/mens-stylish-slide-slipper-sandal-i141964811-s1106498181.html',
#     'lastReviewer': 'Faisal, SamihaFaisal, Samiha',
#     'likeCount': 0,
#     'likeText': None,
#     'originPrice': None,
#     'originalRating': None,
#     'promotion': None,
#     'qcDate': None,
#     'qcReasonId': None,
#     'qcScore': None,
#     'qcTag': None,
#     'rating': 5,
#     'realBuyerName': None,
#     'rejected': False,
#     'rejectionReason': None,
#     'relevanceScore': 60.0,
#     'replies': [{'canReply': False,
#       'helpful': None,
#       'isFollowUp': False,
#       'isMeLike': None,
#       'likeCount': 0,
#       'rejected': False,
#       'rejectionReason': None,
#       'resubmissionMessage': None,
#       'resubmissionTooltip': None,
#       'reviewContent': 'thank you mam...mam 2 tarikh e flash sale e offer chilo..sudhu ekdiner jonno...',
#       'reviewRateId': 18746614564811,
#       'reviewStatus': 'approved',
#       'reviewTime': '6  days ago',
#       'reviewerBadge': None,
#       'reviewerName': 'Sumaiya A.'}],
#     'reportDate': None,
#     'reportStatus': None,
#     'reportTimes': 0,
#     'resubmissionMessage': None,
#     'resubmissionTooltip': None,
#     'reviewContent': 'product valo sondor size o tikh ase ❤️ Shudu beshi lighting kore😂 kintu 27/02/2021 a order korlam 800 taka diye pray kintu delivery pawar por dekhi dam 649 hoye gese😢 ai kemon bichar',
#     'reviewRateId': 18673660564811,
#     'reviewStatus': 'approved',
#     'reviewTime': '1  week ago',
#     'reviewTitle': None,
#     'reviewType': 'PRODUCT_REVIEW',
#     'salesPrice': None,
#     'sellerId': 1036040,
#     'sellerName': None,
#     'showUploader': True,
#     'showVideoUploader': False,
#     'skuId': '1106498181',
#     'skuInfo': 'Color Family:…Green & Black, Size:EU:45',
#     'source': None,
#     'submitInfo': {'network': '4G',
#      'os': 'ios',
#      'source': 'order_detail',
#      'terminal': 'weex'},
#     'tags': None,
#     'targetId': 141964811,
#     'targetType': 'item',
#     'tradeOrderId': None,
#     'upVotes': 0,
#     'videoCoverUrl': None,
#     'videoId': None,
#     'zonedBoughtDate': None,
#     'zonedReviewTime': None}],
#   'paging': {'currentPage': 1, 'totalItems': 32, 'totalPages': 7},
#   'ratings': {'average': 4.9,
#    'imagesCount': 0,
#    'rateCount': 32,
#    'reviewCount': 27,
#    'scores': [29, 3, 0, 0, 0],
#    'videosCount': 0,
#    'withImageCount': 12,
#    'withMediaCount': 12,
#    'withVideoCount': 0}},
#  'msgCode': None,
#  'msgInfo': None,
#  'success': True}

# %% [markdown]
# # Reviews

# %%
# check the review dictionary
for review in review_dict_list['model']['items']:
  print(json.dumps(review, indent = 4))


# check only the reviews
for counter,review in  enumerate(review_dict_list['model']['items'],start=1) :
  print(counter,dict(review)['reviewContent'],sep='\t')
# Out:
# 1	Such a good product. I am happy to got this product. Thanks daraz and sailor. If you interested, can buy.
# 2	original product R 😍😍
# Tnq so much eto vlo product dewar jnno
# apnara  chaile nite paren..
# 3	যেমনটা দেখেছিলাম,যেমন আসা করেছিলাম তেমনটাই পেয়েছি।thank you daraz,thank you daraz mall.
# 4	Thik jemon ta chyci omon tai paice.
# tnxxxx a lot.
# product ta onk vlo deyar jonne.
# ❤❤❤❤
# 5	product valo sondor size o tikh ase ❤️ Shudu beshi lighting kore😂 kintu 27/02/2021 a order korlam 800 taka diye pray kintu delivery pawar por dekhi dam 649 hoye gese😢 ai kemon bichar
